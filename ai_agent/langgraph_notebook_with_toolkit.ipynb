# %% [markdown]
# # LangGraph Agent
# ## _With_ tools

# %% [markdown]
# ## Library Imports

# %%
from langchain_core.messages import HumanMessage
from langchain_anthropic import ChatAnthropic
from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import END, START, StateGraph, MessagesState
import logging
from IPython.display import Image, Markdown, display
from langchain_core.runnables.graph import CurveStyle, MermaidDrawMethod, NodeStyles


from swc_toolkit import SportsWorldCentralToolkit
from langchain_core.tools import tool
from langgraph.prebuilt import ToolNode
from typing import Literal
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File d:\zero\SWC-fantasy-football\ai_agent\swc_toolkit.py:10
#       9 try:
# ---> 10             from swcpy import SWCClient
#      11             from swcpy import SWCConfig
#
# ModuleNotFoundError: No module named 'swcpy'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 10
#       6 from IPython.display import Image, Markdown, display
#       7 from langchain_core.runnables.graph import CurveStyle, MermaidDrawMethod, NodeStyles
# ---> 10 from swc_toolkit import SportsWorldCentralToolkit
#      11 from langchain_core.tools import tool
#      12 from langgraph.prebuilt import ToolNode
#
# File d:\zero\SWC-fantasy-football\ai_agent\swc_toolkit.py:14
#      12             from swcpy.swc_client import League, Team
#      13 except ImportError:
# ---> 14     raise ImportError(
#      15         "swcpy is not installed. Please install it."
#      16     )
#      18 config = SWCConfig(backoff=False)
#      19 local_swc_client = SWCClient(config)
#
# ImportError: swcpy is not installed. Please install it.

# %% [markdown]
# ## Configure logging

# %%
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

logging.basicConfig(
    filename='langgraph_notebook.log',  
    level=logging.INFO,
)
# Out:
# Running cells with '.venv (Python 3.12.10)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/zero/SWC-fantasy-football/ai_agent/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# ## Create toolkit

# %%
swc_toolkit = SportsWorldCentralToolkit()
tools = swc_toolkit.get_tools()

# %% [markdown]
# ## Configure Agent and Model

# %%
tool_node = ToolNode(tools)

model = ChatAnthropic(model="claude-3-5-sonnet-20240620", 
                      temperature=0).bind_tools(tools)

def should_continue(state: MessagesState) -> Literal["tools", END]:
    messages = state['messages']
    last_message = messages[-1]
    if last_message.tool_calls:
        return "tools"
    return END

def call_model(state: MessagesState):
    messages = state['messages']
    response = model.invoke(messages)
    return {"messages": [response]}

workflow = StateGraph(MessagesState)

workflow.add_node("agent", call_model)
workflow.add_node("tools", tool_node)

workflow.add_edge(START, "agent")

workflow.add_conditional_edges(
    "agent",
    should_continue,
)

workflow.add_edge("tools", 'agent')

checkpointer = MemorySaver()

app = workflow.compile(checkpointer=checkpointer)

# %% [markdown]
# ## Visualize the Graph

# %%
display(
    Image(
        app.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %% [markdown]
# ## Chat with the Agent and its tools

# %%
final_state = app.invoke(
    {"messages": [HumanMessage(content="What are the leagues in the SportsWorldCentral fantasy football platform? Keep the response simple.")]},
    config={"configurable": {"thread_id": 99}}
)
display(Markdown(final_state["messages"][-1].content))
