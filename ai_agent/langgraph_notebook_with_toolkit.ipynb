# %% [markdown]
# # LangGraph Agent
# ## _With_ tools

# %% [markdown]
# ## Library Imports

# %%
from langchain_core.messages import HumanMessage
from langchain_anthropic import ChatAnthropic
from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import END, START, StateGraph, MessagesState
import logging
from IPython.display import Image, Markdown, display
from langchain_core.runnables.graph import CurveStyle, MermaidDrawMethod, NodeStyles


from swc_toolkit import SportsWorldCentralToolkit
from langchain_core.tools import tool
from langgraph.prebuilt import ToolNode
from typing import Literal
# Out:
# SWC_API_BASE_URL in SWCConfig init: http://127.0.0.1:8000/

# %% [markdown]
# ## Configure logging

# %%
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

logging.basicConfig(
    filename='langgraph_notebook.log',  
    level=logging.INFO,
)

# %% [markdown]
# ## Create toolkit

# %%
swc_toolkit = SportsWorldCentralToolkit()
tools = swc_toolkit.get_tools()

# %% [markdown]
# ## Configure Agent and Model

# %%
tool_node = ToolNode(tools)

model = ChatAnthropic(model="claude-3-5-sonnet-20240620", 
                      temperature=0).bind_tools(tools)

def should_continue(state: MessagesState) -> Literal["tools", END]:
    messages = state['messages']
    last_message = messages[-1]
    if last_message.tool_calls:
        return "tools"
    return END

def call_model(state: MessagesState):
    messages = state['messages']
    response = model.invoke(messages)
    return {"messages": [response]}

workflow = StateGraph(MessagesState)

workflow.add_node("agent", call_model)
workflow.add_node("tools", tool_node)

workflow.add_edge(START, "agent")

workflow.add_conditional_edges(
    "agent",
    should_continue,
)

workflow.add_edge("tools", 'agent')

checkpointer = MemorySaver()

app = workflow.compile(checkpointer=checkpointer)

# %% [markdown]
# ## Visualize the Graph

# %%
display(
    Image(
        app.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %% [markdown]
# ## Chat with the Agent and its tools

# %%
final_state = app.invoke(
    {"messages": [HumanMessage(content="What are the leagues in the SportsWorldCentral fantasy football platform? Keep the response simple.")]},
    config={"configurable": {"thread_id": 99}}
)
display(Markdown(final_state["messages"][-1].content))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 final_state = app.invoke(
#       2     {"messages": [HumanMessage(content="What are the leagues in the SportsWorldCentral fantasy football platform? Keep the response simple.")]},
#       3     config={"configurable": {"thread_id": 99}}
#       4 )
#       5 display(Markdown(final_state["messages"][-1].content))
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\langgraph\pregel\__init__.py:2336, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    2334 else:
#    2335     chunks = []
# -> 2336 for chunk in self.stream(
#    2337     input,
#    2338     config,
#    2339     stream_mode=stream_mode,
#    2340     output_keys=output_keys,
#    2341     interrupt_before=interrupt_before,
#    2342     interrupt_after=interrupt_after,
#    2343     debug=debug,
#    2344     **kwargs,
#    2345 ):
#    2346     if stream_mode == "values":
#    2347         latest = chunk
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\langgraph\pregel\__init__.py:1993, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1987     # Similarly to Bulk Synchronous Parallel / Pregel model
#    1988     # computation proceeds in steps, while there are channel updates.
#    1989     # Channel updates from step N are only visible in step N+1
#    1990     # channels are guaranteed to be immutable for the duration of the step,
#    1991     # with channel updates applied only at the transition between steps.
#    1992     while loop.tick(input_keys=self.input_channels):
# -> 1993         for _ in runner.tick(
#    1994             loop.tasks.values(),
#    1995             timeout=self.step_timeout,
#    1996             retry_policy=self.retry_policy,
#    1997             get_waiter=get_waiter,
#    1998         ):
#    1999             # emit output
#    2000             yield from output()
#    2001 # emit output
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\langgraph\pregel\runner.py:230, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     228 t = tasks[0]
#     229 try:
# --> 230     run_with_retry(
#     231         t,
#     232         retry_policy,
#     233         configurable={
#     234             CONFIG_KEY_SEND: partial(writer, t),
#     235             CONFIG_KEY_CALL: partial(call, t),
#     236         },
#     237     )
#     238     self.commit(t, None)
#     239 except Exception as exc:
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\langgraph\pregel\retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\langgraph\utils\runnable.py:546, in RunnableSeq.invoke(self, input, config, **kwargs)
#     542 config = patch_config(
#     543     config, callbacks=run_manager.get_child(f"seq:step:{i + 1}")
#     544 )
#     545 if i == 0:
# --> 546     input = step.invoke(input, config, **kwargs)
#     547 else:
#     548     input = step.invoke(input, config)
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\langgraph\utils\runnable.py:310, in RunnableCallable.invoke(self, input, config, **kwargs)
#     308 else:
#     309     context.run(_set_config_context, config)
# --> 310     ret = context.run(self.func, *args, **kwargs)
#     311 if isinstance(ret, Runnable) and self.recurse:
#     312     return ret.invoke(input, config)
#
# Cell In[4], line 15, in call_model(state)
#      13 def call_model(state: MessagesState):
#      14     messages = state['messages']
# ---> 15     response = model.invoke(messages)
#      16     return {"messages": [response]}
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\langchain_core\runnables\base.py:5416, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5409 @override
#    5410 def invoke(
#    5411     self,
#    (...)   5414     **kwargs: Optional[Any],
#    5415 ) -> Output:
# -> 5416     return self.bound.invoke(
#    5417         input,
#    5418         self._merge_configs(config),
#    5419         **{**self.kwargs, **kwargs},
#    5420     )
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:369, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     357 @override
#     358 def invoke(
#     359     self,
#    (...)    364     **kwargs: Any,
#     365 ) -> BaseMessage:
#     366     config = ensure_config(config)
#     367     return cast(
#     368         "ChatGeneration",
# --> 369         self.generate_prompt(
#     370             [self._convert_input(input)],
#     371             stop=stop,
#     372             callbacks=config.get("callbacks"),
#     373             tags=config.get("tags"),
#     374             metadata=config.get("metadata"),
#     375             run_name=config.get("run_name"),
#     376             run_id=config.pop("run_id", None),
#     377             **kwargs,
#     378         ).generations[0][0],
#     379     ).message
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:946, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     937 @override
#     938 def generate_prompt(
#     939     self,
#    (...)    943     **kwargs: Any,
#     944 ) -> LLMResult:
#     945     prompt_messages = [p.to_messages() for p in prompts]
# --> 946     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:765, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     762 for i, m in enumerate(input_messages):
#     763     try:
#     764         results.append(
# --> 765             self._generate_with_cache(
#     766                 m,
#     767                 stop=stop,
#     768                 run_manager=run_managers[i] if run_managers else None,
#     769                 **kwargs,
#     770             )
#     771         )
#     772     except BaseException as e:
#     773         if run_managers:
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1011, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1009     result = generate_from_stream(iter(chunks))
#    1010 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1011     result = self._generate(
#    1012         messages, stop=stop, run_manager=run_manager, **kwargs
#    1013     )
#    1014 else:
#    1015     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:796, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#     794     return generate_from_stream(stream_iter)
#     795 payload = self._get_request_payload(messages, stop=stop, **kwargs)
# --> 796 data = self._client.messages.create(**payload)
#     797 return self._format_output(data, **kwargs)
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\anthropic\_utils\_utils.py:283, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     281             msg = f"Missing required argument: {quote(missing[0])}"
#     282     raise TypeError(msg)
# --> 283 return func(*args, **kwargs)
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\anthropic\resources\messages\messages.py:948, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     941 if model in DEPRECATED_MODELS:
#     942     warnings.warn(
#     943         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     944         DeprecationWarning,
#     945         stacklevel=3,
#     946     )
# --> 948 return self._post(
#     949     "/v1/messages",
#     950     body=maybe_transform(
#     951         {
#     952             "max_tokens": max_tokens,
#     953             "messages": messages,
#     954             "model": model,
#     955             "metadata": metadata,
#     956             "stop_sequences": stop_sequences,
#     957             "stream": stream,
#     958             "system": system,
#     959             "temperature": temperature,
#     960             "thinking": thinking,
#     961             "tool_choice": tool_choice,
#     962             "tools": tools,
#     963             "top_k": top_k,
#     964             "top_p": top_p,
#     965         },
#     966         message_create_params.MessageCreateParamsStreaming
#     967         if stream
#     968         else message_create_params.MessageCreateParamsNonStreaming,
#     969     ),
#     970     options=make_request_options(
#     971         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     972     ),
#     973     cast_to=Message,
#     974     stream=stream or False,
#     975     stream_cls=Stream[RawMessageStreamEvent],
#     976 )
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\anthropic\_base_client.py:1279, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1265 def post(
#    1266     self,
#    1267     path: str,
#    (...)   1274     stream_cls: type[_StreamT] | None = None,
#    1275 ) -> ResponseT | _StreamT:
#    1276     opts = FinalRequestOptions.construct(
#    1277         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1278     )
# -> 1279     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\anthropic\_base_client.py:998, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     995 options = self._prepare_options(options)
#     997 remaining_retries = max_retries - retries_taken
# --> 998 request = self._build_request(options, retries_taken=retries_taken)
#     999 self._prepare_request(request)
#    1001 kwargs: HttpxSendArgs = {}
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\anthropic\_base_client.py:503, in BaseClient._build_request(self, options, retries_taken)
#     500     else:
#     501         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 503 headers = self._build_headers(options, retries_taken=retries_taken)
#     504 params = _merge_mappings(self.default_query, options.params)
#     505 content_type = headers.get("Content-Type")
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\anthropic\_base_client.py:444, in BaseClient._build_headers(self, options, retries_taken)
#     434 custom_headers = options.headers or {}
#     435 headers_dict = _merge_mappings(
#     436     {
#     437         "x-stainless-timeout": str(options.timeout.read)
#    (...)    442     custom_headers,
#     443 )
# --> 444 self._validate_headers(headers_dict, custom_headers)
#     446 # headers are case-insensitive while dictionaries are not.
#     447 headers = httpx.Headers(headers_dict)
#
# File d:\zero\SWC-fantasy-football\.venv\Lib\site-packages\anthropic\_client.py:173, in Anthropic._validate_headers(self, headers, custom_headers)
#     170 if isinstance(custom_headers.get("Authorization"), Omit):
#     171     return
# --> 173 raise TypeError(
#     174     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     175 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"
# During task with name 'agent' and id 'b332d6c4-18e7-e60e-ac1b-129b182aa09a'
